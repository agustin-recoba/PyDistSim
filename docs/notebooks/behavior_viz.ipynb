# %%
# If pydistsim is not installed and the script is run from docs/notebooks directory
# import sys
# sys.path.append("../../")

# for interactive plots
# %matplotlib notebook

from pydistsim.network import NetworkGenerator
from pydistsim.demo_algorithms.broadcast import Flood
from pydistsim.simulation import Simulation
from pydistsim.network.behavior import ExampleProperties
from pydistsim.network.behavior import (
    NetworkBehaviorModel,
    random_loss,
    small_random_increment,
    random_delay_max_size_network,
)

from pydistsim.gui import drawing as draw
from IPython.display import HTML

# %%
net = NetworkGenerator.generate_mesh_network(16)
sim = Simulation(net, (Flood,))

# %%
def make_vid(properties):
    net.behavioral_properties = properties

    sim.check_restrictions = False
    sim.reset()
    anim = draw.create_animation(sim, show_labels=False)
    video = anim.to_html5_video()

    return HTML(video)

# %%
make_vid(ExampleProperties.IdealCommunication)
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
make_vid(ExampleProperties.RandomDelayCommunication)
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
make_vid(ExampleProperties.UnlikelyRandomLossCommunication)
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
make_vid(
    NetworkBehaviorModel(
        message_ordering=True,
        message_delay_indicator=random_delay_max_size_network,
        bounded_communication_delays=True,
        message_loss_indicator=random_loss(0.5),
        clock_increment=small_random_increment,
    )
)
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...
